# %% [markdown]
# # **Laboratorio 6: Refuerzo en el uso de minimize**
# **Facultad de ingeniería**
#
# Departamento de Ingeniería Biomédica
#
# Universidad de los Andes
#
# **IBIO-2440:** Fundamentos del machine learning

# %% [markdown]
# **Nombres de los integrantes**
#
#
# 1.   Nombre integrante 1
# 2.   Nombre integrante 2
#
# **Número del grupo**
#
# *Escribir el número del grupo*

# %% [markdown]
# **Ejercicios 1.1**

# %% [markdown]
# La farmaceutica multinacional "Drugdis" se encuentra en proceso de abrir una sede en Colombia que incluye la apertura de una fábrica para sintetizar 3 medicamentos usados en el tratamiento de la artritis. En un acuerdo de cooperación con el gobierno colombiano se acordó que la empresa comprará los insumos necesarios para la fabricación de los medicamentos a una empresa colombiana. Mediante un proceso de licitación se postularon 3 proveedores de la materia prima que se necesita para fabricar los medicamentos. Los precios que ofrece cada proveedor se presentan en la siguiente tabla:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por otra parte, la farmacéutica requiere las siguientes cantidades de insumos por unidad de medicamento:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La empresa siempre mantiene en su inventario 1600 unidades de insumo 1 y 2000 unidades de insumo 2. Para poder mantener la planta en funcionamiento se deben fabricar al menos 400 unidades entre todos los productos (la suma de las unidades de productos debe ser mayor a 400).
#
# El precio de venta de cada medicamento se presenta a continuación:
#
# **Medicamento 1:** $25
#
# **Medicamento 2:** $20
#
# **Medicamento 3:** $15
#
# Con base en la información suministrada, usted fue contratado como consultor y debe informar a la empresa cuál es el mejor proveedor para comprar los medicamentos y con esto maximizar la ganancia de la farmacéutica. Para esto, debe utilizar la función *minimize()* de **SciPy**.

# %% [markdown]
# **1.** Identifique el tipo de problema de optimización  y explique el por qué de su elección.

# %% [markdown]
# Escriba aquí su respuesta.

# %% [markdown]
# **2.** Defina la función objetivo que maximiza la ganancia de la empresa en función de las unidades vendidas y las restricciones de la materia prima requerida para cada medicamento.

# %%
# Defina en este espacio la función objetivo y las restricciones

# %% [markdown]
# **2.** Ejecute el problema para cada proveedor y responda cuál es la ganancia máxima de la farmacéutica y cuál es el mejor proveedor para comprar los insumos.

# %%
# Ejecute minimize() a partir de su función objetivo y sus restricciones

# %% [markdown]
# Indique aquí cúal de las tres empresas es el mejor proveedor de insumos y por qué.
