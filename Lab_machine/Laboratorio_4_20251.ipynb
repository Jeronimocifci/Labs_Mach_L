# %% [markdown]
# # **Laboratorio 4: Una introducción al pensamiento algorítmico**
# **Facultad de ingeniería**
#
# Departamento de Ingeniería Biomédica
#
# Universidad de los Andes
#
# **IBIO-2340:** Fundamentos del machine learning

# %% [markdown]
# **Nombres de los integrantes**
#
#
# 1.   Alejandro Narváez - 202123110
# 2.   Ali Cifci - 202210698
#
# **Número del grupo**
#
# LabML-4 10

# %% [markdown]
# # **Pseudoalgoritmos**
#
# Un pseudoalgoritmo es una forma generalizada de implementar un algoritmo sin necesidad de incluir la sintaxis de un lenguaje de programación en concreto. Se caracteriza por no ser realmente ejecutable sino una representación de la idea lógica que implica su funcionamiento para que pueda ser transmitida arbitrariamentre.
#
# Dado un pseudoalgoritmo, el programador es libre de llevar a cabo esta idea lógica en cualquier lenguaje de programación y ejecutarla de una manera personalizada. Un ejemplo de pseudoalgoritmo sería el siguiente:

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Este pseudoalgoritmo generaliza la idea del famoso algoritmo *Insertion sort*, que organiza en orden ascendente los números contenidos en un arreglo. Para ello inicia describiendo la información de entrada y la que se obtendrá como resultado, es decir el arreglo desordenado y el arreglo ordenado respectivamente. Luego, muestra el proceso mediante el cual se opera el arreglo para ordenarse, usando estructuras iterativas.

# %% [markdown]
# En particular, podemos implementar este pseudoalgoritmo en Python de la siguiente forma:

# %%
def InsertionSort(A):
  N = len(A)
  for j in range(2,N):
    key = A[j]
    i = j-1
    while (i>=0) and (A[i]>key):
      A[i+1]=A[i]
      i = i-1
    A[i+1] = key
  return A

A = [1, 9, 2, 7, 1, 6, 0, 4]
B = InsertionSort(A)
print(B)
# Out:
# [0, 1, 1, 2, 4, 6, 7, 9]

# %% [markdown]
# Los pseudoalgoritmos son fundamentales para transmitir ideas algorítmicas sin necesidad de restringirlas a un lenguaje de programación en concreto. Estos son muy usados en textos de optimización e inteligencia artificial debido a su versatilidad, por lo que la idea de este laboratorio es familiarizarse con ellos y, posteriormente, ejecutarlos.

# %% [markdown]
# **1. Ejercicio de calentamiento**
#
#
# Considere el siguiente algoritmo:
#
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Interprete y explique con sus palabras la idea lógica que sigue este pseudoalgoritmo. Posteriormente, implemente el pseudoalgoritmo en Python, para ello, defina una función llamada **euclidean_algorithm** que reciba como parámetros dos enteros **a** y **b**.

# %% [markdown]
# ------------------------------
# *Interpretación: (escriba su interpretación aquí)*
# ------------------------------ -

# %%
def gcd(a:int, b:int):
  
  while a != b:
    if a > b:
      a = a - b
      return
  else:
    b = b - a
  return

# %% [markdown]
# El algoritmo que acaba de implementar fue desarrollado por el matemático griego Euclides en su libro *Elementos* que apareció por primera vez cerca del 300 a.C.

# %% [markdown]
# **2. Interpretación e implementación de una rutina de búsqueda**
#
# Considere el siguiente algoritmo:
#
#
#
# ![5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  El objetivo de este algoritmo es simular el cambio continuo de una variable, actualizando el valor de la posición en el paso siguiente $x(k+1)$ a partir del valor de la posición en el paso actual $(x(k))$ y la forma en que cambia $d(k)$ durante $n$ pasos.
#
#  Este es el tipo de algoritmos usados en inteligencia artificial para guiar los procesos de aprendizaje de las máquinas. En este ejemplo, tenemos un proceso iterativo de $n$  pasos que actualiza un arreglo $x$. El algoritmo recibe como parámetros de entrada una condición inicial $x[0]$ y el número de pasos $n$, y debe retornar el arreglo final $x$, que muestra los sucesivos cambios de la variable.

# %% [markdown]
# **2.1.** Implemente el algoritmo anterior como una función llamada ***trajectory*** que recibe como parámetros una condición inicial $x_0$ de tipo float y un número de pasos ***n*** de tipo int y realice una prueba de ejemplo.

# %%
import numpy as np

def trajectory(x0:float, n:int):
    x = np.zeros(n + 1)  # Crear un array para almacenar los valores de x
    x[0] = x0  # Asignar la condición inicial
    for k in range(n):
        d_k = np.cos(x[k]) + (10/3) * np.cos((10/3) * x[k])
        x[k + 1] = x[k] - 0.1 * d_k  # Aplicar la actualización
    return x

x0 = 1.0  # Condición inicial
n = 50  # Número de iteraciones
resultado = trajectory(x0, n)
print(resultado)
# Out:
# [1.         1.27319444 1.39436024 1.39830028 1.3982579  1.39825837
#  1.39825837 1.39825837 1.39825837 1.39825837 1.39825837 1.39825837
#  1.39825837 1.39825837 1.39825837 1.39825837 1.39825837 1.39825837
#  1.39825837 1.39825837 1.39825837 1.39825837 1.39825837 1.39825837
#  1.39825837 1.39825837 1.39825837 1.39825837 1.39825837 1.39825837
#  1.39825837 1.39825837 1.39825837 1.39825837 1.39825837 1.39825837
#  1.39825837 1.39825837 1.39825837 1.39825837 1.39825837 1.39825837
#  1.39825837 1.39825837 1.39825837 1.39825837 1.39825837 1.39825837
#  1.39825837 1.39825837 1.39825837]

# %% [markdown]
# **2.2.** Ahora asuma que $n=11$. Ejecútelo cuatro veces, cada vez con cada una de siguientes condiciones iniciales:
# - $x[0]=3.0$
# - $x[0]=4.0$
# - $x[0]=4.5$
# - $x[0]=6.5$

# %%
# Condiciones iniciales y número de iteraciones
initial_conditions = [3.0, 4.0, 4.5, 6.5]
n = 11
resultados_matriz = [] #Almacenamiento de resultados

# Ejecutar el algoritmo para cada condición inicial
for x0 in initial_conditions:
    resultado = trajectory(x0, n)
    resultados_matriz.append(resultado)  # Guardar en la matriz
    print(f"Resultados para x[0] = {x0}:\n{resultado}\n")
# Out:
# Resultados para x[0] = 3.0:
# [3.         3.37868976 3.38803429 3.38718366 3.38725767 3.3872512
#  3.38725176 3.38725171 3.38725172 3.38725172 3.38725172 3.38725172]
#
# Resultados para x[0] = 4.0:
# [4.         3.82535712 3.57522068 3.40039618 3.38619277 3.38734476
#  3.3872436  3.38725243 3.38725166 3.38725172 3.38725172 3.38725172]
#
# Resultados para x[0] = 4.5:
# [4.5        4.77430888 5.09437922 5.15481131 5.14396752 5.14607582
#  5.14566954 5.14574798 5.14573284 5.14573576 5.1457352  5.14573531]
#
# Resultados para x[0] = 6.5:
# [6.5        6.71827991 6.93421103 6.99902509 7.00016731 7.00014881
#  7.00014912 7.00014912 7.00014912 7.00014912 7.00014912 7.00014912]
#
# Matriz de resultados: [3.         3.37868976 3.38803429 3.38718366 3.38725767 3.3872512
#  3.38725176 3.38725171 3.38725172 3.38725172 3.38725172 3.38725172]

# %% [markdown]
# **2.2.** En una figura incluya cuatro subplots y en cada subplot grafique la trayectoria resultante de $x$ para cada una de las condiciones iniciales anteriores. Haga cada gráfico de tipo *scatter*, el eje horizontal corresponde al número de pasos que va de 0 a 10 y el eje vertical corresponde a la posición $x$. Agregue como título general *Trayectoria*.

# %%
import matplotlib.pyplot as plt

# Crear figura con 4 subgráficos
fig, axes = plt.subplots(2, 2, figsize=(10, 8))  
fig.suptitle("Trayectoria", fontsize=16)

# Iterar sobre cada condición inicial y graficar en los subplots
for i, x0 in enumerate(initial_conditions):
    row, col = divmod(i, 2)  # Para ubicar cada subplot en una cuadrícula 2x2
    x_values = trajectory(x0, n) 
    axes[row, col].scatter(steps, x_values, color='b', label=f"x[0] = {x0}")
    axes[row, col].set_xlabel("Número de pasos")
    axes[row, col].set_ylabel("Posición x")
    axes[row, col].legend()
    axes[row, col].grid(True)

# Mostrar la gráfica
plt.tight_layout(rect=[0, 0, 1, 0.96])  
plt.show()

# %% [markdown]
# **2.3** Considere la siguiente función:
#
# \begin{align*}
#   f(x) = \sin(x) + \sin \left(\frac{10}{3}x \right).
# \end{align*}
# Grafique $f(x)$ respecto a $x$, donde $x\in [2.7,7.5]$. Esta gráfica debe verse como una curva continua. Sobre esta gráfica, usando un color diferente, traslape todas las coordenadas $(x[k], f(x[k]))$, donde $x[k]$ es el valor del arreglo con índice $k$ generado con la condición inicial $x[0]=3.0$ que se calculó anteriormente. Su gráfica debería ser similar al siguiente ejemplo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Definir la función f(x)
def f(x):
    return np.sin(x) + np.sin((10/3) * x)

# Rango de x
x = np.linspace(2.7, 7.5, 400)
y = f(x)

# Valores de x[k] dados
x_k = np.array([resultados_matriz[0]])
y_k = f(x_k)

# Graficar la función
plt.figure(figsize=(8,6))
plt.plot(x, y, label=r'$f(x) = \sin(x) + \sin(\frac{10}{3} x)$', color='blue')

# Superponer los puntos
plt.scatter(x_k, y_k, color='red', label='Puntos $x[k]$', zorder=3)

# Etiquetas y título
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.title('Trayectoria')
plt.legend()
plt.grid(True)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# **2.4.** Repita el enunciado 2.3 para las otras tres condiciones iniciales. Hágalo en un mismo gráfico pero asigne a cada condición un color diferente.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) Definir la función f(x)
def f(x):
    return np.sin(x) + np.sin((10/3) * x)

# 2) Rango continuo de x para graficar la función
x_vals = np.linspace(2.7, 7.5, 400)
y_vals = f(x_vals)

# 3) Colocar los resultados que ya calculaste
#    (cada uno corresponde a una condición inicial distinta)
x_CI_3_0 = np.array([
    3.0, 3.37868976, 3.38803429, 3.38718366,
    3.38725767, 3.3872512, 3.38725176, 3.38725171,
    3.38725172, 3.38725172, 3.38725172, 3.38725172
])

x_CI_4_0 = np.array([
    4.0, 3.82535712, 3.57522068, 3.40039618,
    3.38619277, 3.38734476, 3.3872436, 3.38725243,
    3.38725166, 3.38725172, 3.38725172, 3.38725172
])

x_CI_4_5 = np.array([
    4.5, 4.77430888, 5.09437922, 5.15481131,
    5.14396752, 5.14607582, 5.14566954, 5.14574798,
    5.14573284, 5.14573576, 5.1457352, 5.14573531
])

x_CI_6_5 = np.array([
    6.5, 6.71827991, 6.93421103, 6.99902509,
    7.00016731, 7.00014881, 7.00014912, 7.00014912,
    7.00014912, 7.00014912, 7.00014912, 7.00014912
])

# 4) Calcular f(x) para cada uno de esos puntos
y_CI_3_0 = f(x_CI_3_0)
y_CI_4_0 = f(x_CI_4_0)
y_CI_4_5 = f(x_CI_4_5)
y_CI_6_5 = f(x_CI_6_5)

# 5) Crear la figura
plt.figure(figsize=(8,6))

# 6) Graficar la función continua
plt.plot(x_vals, y_vals, color='black', label=r'$f(x) = \sin(x) + \sin\left(\frac{10}{3} x\right)$')

# 7) Superponer las diferentes secuencias (cada una con un color distinto)
plt.scatter(x_CI_3_0, y_CI_3_0, color='red',   label='CI: x[0] = 3.0', zorder=3)
plt.scatter(x_CI_4_0, y_CI_4_0, color='blue',  label='CI: x[0] = 4.0', zorder=3)
plt.scatter(x_CI_4_5, y_CI_4_5, color='green', label='CI: x[0] = 4.5', zorder=3)
plt.scatter(x_CI_6_5, y_CI_6_5, color='orange',label='CI: x[0] = 6.5', zorder=3)

# 8) Personalizar la gráfica
plt.title('Trayectoria de f(x) con distintas condiciones iniciales')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()

# 9) Mostrar la gráfica
plt.show()

# %% [markdown]
# **2.5.** A continuación analice los resultados obtenidos y describa el funcionamiento del algoritmo: ¿Qué hace el conjunto de puntos ($x$, $f(x)$)? ¿De que depende el número de puntos que se ve en cada caso?. Finalmente asígnele un nombre.

# %% [markdown]
# ------------------------------
# *Interpretación: (escriba su interpretación aquí)
# *El conjunto de puntos
# (
# 𝑥
# ,
# 𝑓
# (
# 𝑥
# )
# )
# (x,f(x)) representa, en cada iteración, los valores que va tomando la variable
# 𝑥
# x y la evaluación correspondiente de la función
# 𝑓
# (
# 𝑥
# )
# f(x) a lo largo de un proceso iterativo propio de técnicas de machine learning (o de algún método numérico cercano, como Newton-Raphson). A medida que la iteración avanza y los valores se aproximan a una solución (por ejemplo, un cero de la función), los puntos en la gráfica aparecen cada vez más juntos, hasta el punto de que, por la resolución o dimensión de la imagen, pueden verse casi como un solo punto. El número de puntos visibles en cada caso depende tanto de la cercanía de la condición inicial con la solución (lo que puede acelerar o retrasar la convergencia) como de los criterios de parada (tolerancia o límite de iteraciones). A este procedimiento se le suele denominar método iterativo (por ejemplo, método de Newton, método de punto fijo o alguna variante propia de algoritmos de machine learning), ya que consiste en actualizar sucesivamente el valor de
# 𝑥
# x hasta satisfacer un objetivo o criterio específico.
# ------------------------------ -
